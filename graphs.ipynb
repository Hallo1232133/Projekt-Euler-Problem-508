# %%
# to convert to Carthesian
testDataToCarthesianGeneral = [10 ** 2, 10 ** 3, 10 ** 4, 10 ** 5, 10 ** 6, 10  ** 7]
testDataToCarthesianAllOnes = [2097151, 16777215, 268435455]
testDataToCatthesianPowerOf2 = [262144, 1048576, 16777216]

# time taken for conversion
resultsToCarthesianGeneral = [(2.248083, 1.096835), (3.412887, 2.391448), (3.223671, 2.907120), (3.797234, 3.898807), (4.149812, 5.807309), (4.770354, 6.710814)]
resultsToCarthesianAllOnes = [(8.806988, 11.944905), (9.944840, 16.079371), (11.396339, 22.141871)]
resultsToCatthesianPowerOf2 = [(2.368342, 1.996967), (2.480577, 2.200644), (2.694477, 2.594567)]

#testDataToBm1pi = [10 ** 2, 10 ** 2, 10 ** 2, 10 ** 2, 10 ** 2,]

# %%
# splitting results in terms of versions
resultsToCarthesianGeneralV0, resultsToCarthesianGeneralV1 = zip(*resultsToCarthesianGeneral)
resultsToCarthesianAllOnesV0, resultsToCarthesianAllOnesV1 = zip(*resultsToCarthesianAllOnes)
resultsToCatthesianPowerOf2V0, resultsToCatthesianPowerOf2V1 = zip(*resultsToCatthesianPowerOf2)

# %%
# graph general
import matplotlib.pyplot as plt

plt.scatter(x = testDataToCarthesianGeneral, y = resultsToCarthesianGeneralV0, c = "orange")
plt.scatter(x = testDataToCarthesianGeneral, y = resultsToCarthesianGeneralV1, c = "blue")
plt.scatter(x = testDataToCarthesianAllOnes, y = resultsToCarthesianAllOnesV0, c = "red")
plt.scatter(x = testDataToCarthesianAllOnes, y = resultsToCarthesianAllOnesV1, c = "darkblue")
plt.scatter(x = testDataToCarthesianAllOnes, y = resultsToCatthesianPowerOf2V0, c = "yellow")
plt.scatter(x = testDataToCarthesianAllOnes, y = resultsToCatthesianPowerOf2V1, c = "cyan")

plt.xscale('log')
plt.show()
